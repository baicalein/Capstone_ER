# %%
from agent_system.graph import build_graph

graph = build_graph()

initial_state = {
    "clinical_question": "Does this ED patient have any drug allergies that affect current medications?"
}

result = graph.invoke(initial_state)
result
# Out:
# {'clinical_question': 'Does this ED patient have any drug allergies that affect current medications?',
#  'requirements': {'goal': 'drug safety',
#   'care_setting': 'ED',
#   'time_window': 'next 12 hours',
#   'risk_focus': 'drug allergy'},
#  'fhir_mapping': {'AllergyIntolerance': ['clinicalStatus',
#    'verificationStatus',
#    'code',
#    'reaction',
#    'criticality'],
#   'MedicationRequest': ['medicationCodeableConcept', 'authoredOn', 'status'],
#   'Encounter': ['period.start', 'class']}}

# %%
from agent_system.graph_llm import build_graph_llm

graph = build_graph_llm()

result = graph.invoke({
    "clinical_question": "Does this ED patient have any drug allergies that affect current medications?"
})

result
# Out:
# {'clinical_question': 'Does this ED patient have any drug allergies that affect current medications?',
#  'requirements': {'goal': 'drug safety',
#   'care_setting': 'ED',
#   'time_window': 'next 12 hours',
#   'risk_focus': 'drug allergy',
#   'llm_raw_output': '{\n  "goal": "identify_drug_allergies_affecting_current_medications",\n  "care_setting": "emergency_department",\n  "time_window": "current_encounter",\n  "risk_focus": "allergic_reactions_to_current_medications"\n}'},
#  'fhir_mapping': {'AllergyIntolerance': ['clinicalStatus',
#    'verificationStatus',
#    'code',
#    'reaction',
#    'criticality'],
#   'MedicationRequest': ['medicationCodeableConcept', 'authoredOn', 'status'],
#   'Encounter': ['period.start', 'class']}}
